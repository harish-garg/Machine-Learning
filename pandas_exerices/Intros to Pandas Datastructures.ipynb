# %%
This notebook is based on the "Intro to pandas data structures" by Greg Reda(http://www.gregreda.com/2013/10/26/intro-to-pandas-data-structures//)

# %%
# import and configure the required modules.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('max_columns', 50)
# %matplotlib inline

# %%
# Series
s = pd.Series([8, 'This is a string', 3.14, -1.423423423423, "Another string!"])
s
# Out:
# 0                   8
# 1    This is a string
# 2                3.14
# 3            -1.42342
# 4     Another string!
# dtype: object

# %%
d = {'New Delhi': 11, 'Bombay': 22, 'Kolkata': 33, 'Chennai': 44, 'Bangalore': 80}
cities = pd.Series(d)
cities
# Out:
# Bangalore    80
# Bombay       22
# Chennai      44
# Kolkata      33
# New Delhi    11
# dtype: int64

# %%
cities['Bangalore']
# Out:
# 80

# %%
cities[['Bangalore', 'Kolkata', 'Bombay']]
# Out:
# Bangalore    80
# Kolkata      33
# Bombay       22
# dtype: int64

# %%
cities < 20
# Out:
# Bangalore    False
# Bombay       False
# Chennai      False
# Kolkata      False
# New Delhi     True
# dtype: bool

# %%
cities > 20
# Out:
# Bangalore     True
# Bombay        True
# Chennai       True
# Kolkata       True
# New Delhi    False
# dtype: bool

# %%
cities[cities > 20]
# Out:
# Bangalore    80
# Bombay       22
# Chennai      44
# Kolkata      33
# dtype: int64

# %%
print 'old value:', cities['Bangalore']
cities['Bangalore'] = 90
print 'New value:', cities['Bangalore']
# Out:
# old value: 80
# New value: 90

# %%
cities
# Out:
# Bangalore    90
# Bombay       22
# Chennai      44
# Kolkata      33
# New Delhi    11
# dtype: int64

# %%
print(cities[cities < 90])
print('\n')
cities[cities < 90] = 750

print cities[cities < 90]
# Out:
# Bombay       22
# Chennai      44
# Kolkata      33
# New Delhi    11
# dtype: int64
#
#
# Series([], dtype: int64)

# %%
cities
# Out:
# Bangalore     90
# Bombay       750
# Chennai      750
# Kolkata      750
# New Delhi    750
# dtype: int64

# %%
print 'Bangalore' in cities
print 'Mysore' in cities
# Out:
# True
# False

# %%
cities / 3
# Out:
# Bangalore     30.0
# Bombay       250.0
# Chennai      250.0
# Kolkata      250.0
# New Delhi    250.0
# dtype: float64

# %%
np.square(cities)
# Out:
# Bangalore      8100
# Bombay       562500
# Chennai      562500
# Kolkata      562500
# New Delhi    562500
# dtype: int64

# %%
cities[['New Delhi', 'Bombay', 'Mangalore']]
# Out:
# New Delhi    750.0
# Bombay       750.0
# Mangalore      NaN
# dtype: float64

# %%
cities[['New Delhi', 'Bombay', 'Mangalore']] + cities[['Bangalore', 'Mysore']]
# Out:
# Bangalore   NaN
# Bombay      NaN
# Mangalore   NaN
# Mysore      NaN
# New Delhi   NaN
# dtype: float64

# %%
cities.notnull()
# Out:
# Bangalore    True
# Bombay       True
# Chennai      True
# Kolkata      True
# New Delhi    True
# dtype: bool

# %%
cities.isnull()
# Out:
# Bangalore    False
# Bombay       False
# Chennai      False
# Kolkata      False
# New Delhi    False
# dtype: bool

# %%
data = {'year': [2010, 2011, 2012, 2011, 2012, 2010, 2011, 2012],
       'team': ['Bears', 'Bears', 'Bears', 'Packers', 'Packers', 'Lions', 'Lions', 'Lions'],
       'wins': [11, 8, 10, 15, 11, 6, 10, 4],
       'losses': }
# Out:
# I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aavni. I Love Aav ...
